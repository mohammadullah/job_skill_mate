# %%
import re
import operator
from pyspark.sql import SparkSession
import pyspark.sql.functions as f
from pyspark.ml.feature import Tokenizer, RegexTokenizer, StopWordsRemover
from pyspark.sql.functions import udf, concat_ws, lit, col, explode
from pyspark.sql.types import StringType,FloatType

spark = SparkSession.builder.appName('er').getOrCreate()
spark.sparkContext.setLogLevel('WARN')

# %%
job_details=spark.read.option('compression', 'gzip').json('er_resume_preprocessed')
job_details.registerTempTable("job_details")
job_details.show()
# Out:
# +-----------+--------------------+--------------------+----------------+
# |         id|         job_details|           job_title|       resume_id|
# +-----------+--------------------+--------------------+----------------+
# |25769803776|[accepting, calls...|     [office, clerk]|7b9c4b06a9e8eff1|
# |25769803777|[print, scan, shr...|     [office, clerk]|75fd84276b7f61ce|
# |25769803778|[enter, mails, fi...|     [office, clerk]|af70af4861df88f0|
# |25769803779|[office, loading,...|     [office, clerk]|7f2b13910db89d24|
# |25769803780|[328, north, rive...|     [office, clerk]|c7e51c2ae59abc4b|
# |25769803781|[responsibilities...|     [office, clerk]|90213a5d4c0ea6be|
# |25769803782|[lower, sackville...|     [office, clerk]|67761a732de12577|
# |25769803783|[performed, routi...|     [office, clerk]|69c935a303746b81|
# |25769803784|[cameroon, answer...|     [office, clerk]|2efbb1e161bee89d|
# |25769803785|[input, data, com...|     [office, clerk]|b1340a1ce0961fa6|
# |25769803786|[handled, filing,...|       [file, clerk]|b1340a1ce0961fa6|
# |25769803787|[filing, inspecti...|     [office, clerk]|b43fcc3c46751405|
# |25769803788|                  []|     [office, clerk]|04c7f59c7aeb0897|
# |25769803789|                  []|     [office, clerk]|043bcba403828f3a|
# |25769803790|[answer, telephon...|[receptionist/, o...|043bcba403828f3a|
# |25769803791|[provided, servic...| [customer, service]|043bcba403828f3a|
# |25769803792|[meeting, custome...|     [liqour, clerk]|6e4b36973b3a9fe0|
# |25769803793|                  []|             [owner]|6e4b36973b3a9fe0|
# |25769803794|                  []|     [office, clerk]|6e4b36973b3a9fe0|
# |25769803795|[working, special...|[data, entry, clerk]|1b55d0665a3c27f4|
# +-----------+--------------------+--------------------+----------------+
# only showing top 20 rows

# %%
job_titles=spark.read.option('compression', 'gzip').json('er_titles_preprocessed')
job_titles.registerTempTable("job_titles")
job_titles.show()
# Out:
# +--------------------+--------------+----------------+---+
# |     Alternate Title|O*NET-SOC Code|           Title| id|
# +--------------------+--------------+----------------+---+
# |[aeronautics, com...|    11-1011.00|Chief Executives|  0|
# |[agricultural, se...|    11-1011.00|Chief Executives|  1|
# |[alcohol, drug, a...|    11-1011.00|Chief Executives|  2|
# |[arts, humanities...|    11-1011.00|Chief Executives|  3|
# |   [bakery, manager]|    11-1011.00|Chief Executives|  4|
# |   [bank, president]|    11-1011.00|Chief Executives|  5|
# |   [book, publisher]|    11-1011.00|Chief Executives|  6|
# |[brokerage, offic...|    11-1011.00|Chief Executives|  7|
# |     [bureau, chief]|    11-1011.00|Chief Executives|  8|
# |[business, develo...|    11-1011.00|Chief Executives|  9|
# |[business, develo...|    11-1011.00|Chief Executives| 10|
# |[business, enterp...|    11-1011.00|Chief Executives| 11|
# |[business, execut...|    11-1011.00|Chief Executives| 12|
# | [cemetery, manager]|    11-1011.00|Chief Executives| 13|
# |          [chairman]|    11-1011.00|Chief Executives| 14|
# |        [chancellor]|    11-1011.00|Chief Executives| 15|
# |[chief, administr...|    11-1011.00|Chief Executives| 16|
# |[chief, diversity...|    11-1011.00|Chief Executives| 17|
# |[chief, executive...|    11-1011.00|Chief Executives| 18|
# |[chief, financial...|    11-1011.00|Chief Executives| 19|
# +--------------------+--------------+----------------+---+
# only showing top 20 rows

# %%
resume_ids = spark.read.option('compression', 'gzip').json('er_result')
resume_ids.registerTempTable("resume_ids")
resume_ids.show()
# Out:
# +--------------+-----+---+------------------+----------------+
# |O*NET-SOC Code|  id1|id2|           jaccard|       resume_id|
# +--------------+-----+---+------------------+----------------+
# |    15-1133.00| 4885| 65|0.6666666666666666|93de10bb2dd5b81f|
# |    41-9031.00|24724| 65|               0.5|93de10bb2dd5b81f|
# |    15-1132.00| 4833| 65|               0.5|93de10bb2dd5b81f|
# |    15-1199.01| 5285| 65|               0.5|93de10bb2dd5b81f|
# |    17-2141.01| 6725| 65|               0.5|93de10bb2dd5b81f|
# |    17-2141.02| 6747| 65|               0.5|93de10bb2dd5b81f|
# |    15-1133.00| 4882| 65|               0.5|93de10bb2dd5b81f|
# |    15-1132.00| 4845| 65|               0.5|93de10bb2dd5b81f|
# |    15-1199.02| 5309| 65|               0.5|93de10bb2dd5b81f|
# |    17-2199.05| 7020| 65|               0.5|93de10bb2dd5b81f|
# |    15-1199.01| 5282| 65|               0.5|93de10bb2dd5b81f|
# |    15-1134.00| 4942| 65|               0.5|93de10bb2dd5b81f|
# |    17-2199.05| 7021| 65|               0.5|93de10bb2dd5b81f|
# |    15-1133.00| 4887| 65|               0.5|93de10bb2dd5b81f|
# |    15-1111.00| 4578| 65|               0.5|93de10bb2dd5b81f|
# |    15-1132.00| 4828| 65|               0.5|93de10bb2dd5b81f|
# |    17-2141.01| 6723| 65|               0.5|93de10bb2dd5b81f|
# |    15-1132.00| 4834| 65|               0.5|93de10bb2dd5b81f|
# |    17-2111.02| 6430| 65|0.6666666666666666|93de10bb2dd5b81f|
# |    17-2199.10| 7093| 65|               0.5|93de10bb2dd5b81f|
# +--------------+-----+---+------------------+----------------+
# only showing top 20 rows

# %%
joined_data=spark.sql("SELECT a.`Alternate Title`as alternate_title,a.`O*NET-SOC Code` as onet_code, a.Title, b.id1, b.id2, b.jaccard, b.resume_id, c.job_details, c.job_title FROM job_titles a JOIN resume_ids b ON a.id = b.id1 JOIN job_details c ON b.id2 = c.id")
joined_data.registerTempTable("data")

# %%
joined_data.show()
# Out:
# +--------------------+----------+--------------------+-----+---+------------------+----------------+--------------------+--------------------+
# |     alternate_title| onet_code|               Title|  id1|id2|           jaccard|       resume_id|         job_details|           job_title|
# +--------------------+----------+--------------------+-----+---+------------------+----------------+--------------------+--------------------+
# |[software, system...|15-1199.02|Computer Systems ...| 5310| 26|0.6666666666666666|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |[software, system...|15-1133.00|Software Develope...| 4887| 26|0.6666666666666666|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |          [engineer]|17-3023.03|Electrical Engine...| 7466| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |          [engineer]|17-2161.00|   Nuclear Engineers| 6787| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |[software, engineer]|15-1111.00|Computer and Info...| 4579| 26|               1.0|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |[software, qualit...|15-1199.01|Software Quality ...| 5282| 26|0.6666666666666666|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |          [engineer]|27-2012.05|Technical Directo...|15571| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |[software, develo...|15-1199.02|Computer Systems ...| 5309| 26|0.6666666666666666|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |[software, qualit...|15-1199.01|Software Quality ...| 5281| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |          [engineer]|17-3012.02| Electrical Drafters| 7262| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |          [engineer]|17-2021.00|Agricultural Engi...| 5974| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |          [engineer]|53-5031.00|      Ship Engineers|56261| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |[software, requir...|15-1132.00|Software Develope...| 4834| 26|0.6666666666666666|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |          [engineer]|17-2051.00|     Civil Engineers| 6076| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |[drone, software,...|15-1132.00|Software Develope...| 4800| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |          [engineer]|17-2199.10|Wind Energy Engin...| 7086| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |[systems, softwar...|15-1133.00|Software Develope...| 4898| 26|0.6666666666666666|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |          [engineer]|17-2061.00|Computer Hardware...| 6161| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |          [engineer]|53-4013.00|Rail Yard Enginee...|55790| 26|               0.5|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# |[senior, software...|15-1133.00|Software Develope...| 4879| 26|0.6666666666666666|388daff777202464|[cairo, egypt, se...|[software, engineer]|
# +--------------------+----------+--------------------+-----+---+------------------+----------------+--------------------+--------------------+
# only showing top 20 rows

# %%
jaccard_data = spark.sql("SELECT count(alternate_title) as count FROM data where jaccard < 0.6 and jaccard = 0.5 ")
jaccard_data.show()
# Out:
# +--------+
# |   count|
# +--------+
# |13474334|
# +--------+

# %%
grouped_data = spark.sql("SELECT alternate_title,id1 FROM data group by alternate_title, id1")
grouped_data.show()
joined_data.registerTempTable("grouped_data")
# Out:
# +--------------------+-----+
# |     alternate_title|  id1|
# +--------------------+-----+
# |[web, software, e...| 4942|
# |         [professor]|13551|
# |[assistant, profe...|12793|
# |[system, developm...| 7022|
# |  [road, consultant]|26488|
# |[engineering, con...| 6878|
# |[security, consul...|20580|
# |[supplier, qualit...| 4838|
# |[supplier, qualit...| 6580|
# |[operations, anal...| 3413|
# |[compliance, anal...| 3092|
# |[continuous, impr...| 3344|
# |[quality, special...|10190|
# |[graphics, specia...|15226|
# |[sales, support, ...|23862|
# | [wildlife, manager]| 8280|
# |[substation, mana...| 1032|
# | [resident, manager]| 1802|
# | [planning, manager]| 8872|
# |     [band, manager]| 2580|
# +--------------------+-----+
# only showing top 20 rows

# %%
job_titles_d = spark.sql("SELECT job_title FROM data group by job_title")

# %%
job_titles_df = job_titles_d.toPandas()
job_titles_df.head()
# Out:
#                                   job_title
# 0                 [front, desk, supervisor]
# 1                     [janitor, lead, hand]
# 2  [investment, operations, representative]
# 3                        [mobile, operator]
# 4                           [program, host]

# %%
titles_list = []
for j in job_titles_df['job_title']:
    for i in j:
        titles_list.append(i)
titles_list
# Out:
# ['front',
#  'desk',
#  'supervisor',
#  'janitor',
#  'lead',
#  'hand',
#  'investment',
#  'operations',
#  'representative',
#  'mobile',
#  'operator',
#  'program',
#  'host',
#  'disbursement',
#  'clerk',
#  'payroll',
#  'clerk',
#  'iii',
#  'temporary',
#  'customer',
#  'service',
#  'cashier',
#  'data',
#  'processing',
#  'manager/lead',
#  'support',
#  'agent',
#  'hbc',
#  'librarian',
#  'coat',
#  'check',
#  'clothing',
#  'sales',
#  'associate',
#  'cashier',
#  'payroll/maintenance',
#  'administrator',
#  'recreation',
#  'worker',
#  'senior',
#  'application',
#  'developer',
#  'assistant',
#  'design',
#  'engineer',
#  'machinist',
#  'student',
#  'athletics',
#  'director',
#  'cultural',
#  'assistant',
#  'waiter',
#  'china',
#  'data',
#  'analyst',
#  'assistant',
#  'accounts',
#  'payable',
#  'coordinator',
#  'western',
#  'canada',
#  'operator/accounting/office',
#  'administrator',
#  'wireless',
#  'services',
#  'manager',
#  'host/server/room',
#  'attendant',
#  'order',
#  'processing',
#  'clerk',
#  'trainer',
#  'full-time',
#  'hospital',
#  'representative',
#  'feb/2005',
#  'service',
#  'clerk',
#  'cashier',
#  'human',
#  'resources',
#  'office',
#  'manager',
#  'census',
#  'enumerator',
#  'senior',
#  'software',
#  'automation',
#  'test',
#  'engineer',
#  'commercial',
#  'director',
#  'personal',
#  'health',
#  'coach',
#  'account',
#  'receivable',
#  'clerk',
#  '/receptionist',
#  'regional',
#  'project',
#  'manager',
#  'customer',
#  'service',
#  'secretary',
#  'technical',
#  'consultant',
#  'call',
#  'center',
#  'customer',
#  'manager',
#  'consumer',
#  'inside',
#  'sales',
#  'dispatch',
#  'office',
#  'representative',
#  'hair',
#  'stylist',
#  'training',
#  'flagman',
#  'contractor',
#  'software',
#  'engineer',
#  'account',
#  'manager/business',
#  'development',
#  'administrative',
#  'clerk',
#  'bookkeeper',
#  'process',
#  'control',
#  'specialist',
#  'engineer',
#  'turf',
#  'installation',
#  'crew',
#  'member',
#  'financial',
#  'analyst',
#  'co-op',
#  'administrator/billing',
#  'clerk',
#  'jr.',
#  'database',
#  'developer',
#  'freelance',
#  'performer',
#  'service',
#  'consultant',
#  'pastry',
#  'prep',
#  'cook',
#  'part-time',
#  'duty',
#  'manager',
#  'loans',
#  'clerk',
#  'roofing',
#  'technician',
#  'custodian',
#  'superintendent',
#  'data',
#  'entry',
#  'clerk',
#  'office',
#  'administrator',
#  'backend',
#  'developer',
#  'payroll/accounting',
#  'administrator',
#  'guest',
#  'service',
#  'agent',
#  'front',
#  'desk',
#  'concierge',
#  'desktop',
#  'support',
#  'sr.',
#  'level',
#  'apartment',
#  'host',
#  'cleaner',
#  'part-time',
#  'club',
#  'services',
#  'assistant',
#  'product',
#  'process',
#  'specialist',
#  'financial',
#  'analyst',
#  'project',
#  'accountant',
#  'assistant',
#  'soccer',
#  'coach',
#  'manager',
#  'insight',
#  'services',
#  'assistant',
#  'personal',
#  'financial',
#  'manager',
#  'graveyard',
#  'baker',
#  'commercial',
#  'cleaner',
#  'subcontractor',
#  'odi',
#  'consultant',
#  'asst',
#  'finance',
#  'manager',
#  'senior',
#  'representative',
#  'inside',
#  'sales',
#  'international',
#  'travel',
#  'consultant',
#  'assistant',
#  'team',
#  'leader',
#  'home',
#  'sales',
#  'representative/cdg',
#  'accounting',
#  'clerk',
#  'truck',
#  'driver',
#  'camping',
#  'office',
#  'clerk',
#  'subway',
#  'janitor',
#  'manager',
#  'operational',
#  'accounting',
#  'r',
#  'director',
#  'business',
#  'development',
#  'lead',
#  'generation',
#  'representative',
#  'interpreter-translator-sales',
#  'manager',
#  'cashier/baker',
#  'supervisor',
#  'analyst',
#  'financial',
#  'strategic',
#  'planning',
#  'cashier/gas',
#  'pump',
#  'attendant',
#  'proprietor',
#  'manager',
#  'artist',
#  'residency',
#  'cook',
#  'back',
#  'customer',
#  'service',
#  'representant',
#  'senior',
#  'devops',
#  'engineer',
#  'controller/director',
#  'financial',
#  'systems',
#  'qa',
#  'tester',
#  'cum',
#  'customer',
#  'support',
#  'engineer',
#  'volunteer',
#  'assistant',
#  'secretary',
#  'hostess',
#  'food',
#  'expediter',
#  'software',
#  'engineer',
#  'application',
#  'development',
#  'student',
#  'programs',
#  'coordinator',
#  'ticket',
#  'agent',
#  'data',
#  'analyst',
#  'remote',
#  'sensing',
#  'talking',
#  'sales',
#  'representative',
#  '1',
#  'working',
#  'software',
#  'engineer',
#  'lead',
#  'solution',
#  'technology',
#  'architect',
#  'project',
#  'manager',
#  'staff',
#  'supervisor',
#  'journeyman',
#  'carpenter',
#  'greeter',
#  'volunteer',
#  'pantry',
#  'chef',
#  'full-time',
#  'legal',
#  'secretary',
#  'station',
#  'attendant',
#  'part-time',
#  'audit',
#  'assistant',
#  'audit',
#  'senior',
#  'fundraising',
#  'sales',
#  'representative',
#  'commis',
#  'pastry',
#  'cook',
#  'technician',
#  "'s",
#  'assistant',
#  'production',
#  'clerk',
#  'planning',
#  'scheduling',
#  'contract',
#  'senior',
#  'project',
#  'analyst',
#  'founder',
#  'president',
#  'public',
#  'health',
#  'program',
#  'assistant',
#  'payroll',
#  'supervisor',
#  'human',
#  'resources',
#  'mobile',
#  'field',
#  'supervisor',
#  'territory',
#  'manager',
#  'saskatchewan',
#  'receptionist/administrative',
#  'clerk',
#  'contract',
#  'lead',
#  'business',
#  'analyst',
#  'technical',
#  'lead',
#  'english',
#  'language',
#  'canadian',
#  'culture',
#  'tutor',
#  'shipper',
#  'bunking',
#  'order',
#  'picker',
#  'customer',
#  'service',
#  'representative',
#  'fido',
#  'coordinator',
#  'ceremonies',
#  'european',
#  'financial',
#  'analyst/finance',
#  'manager',
#  'associate',
#  'process',
#  'manager',
#  'part-time',
#  'retail',
#  'sales',
#  'associate',
#  'journeyman',
#  'scaffolder',
#  'customer',
#  'service',
#  'specialist',
#  'part-time',
#  'lead',
#  'software',
#  'engineer',
#  'testing',
#  'data',
#  'entry/office',
#  'administrator',
#  'credit',
#  'officer',
#  'us',
#  'department',
#  'pet',
#  'stylist',
#  'sales',
#  'marketer',
#  'waiter/laundry',
#  'attendant',
#  'accounting',
#  'reporting',
#  'manager',
#  'office',
#  'assistant',
#  'product',
#  'boxer',
#  'systems',
#  'data',
#  'analyst',
#  'operations',
#  'service',
#  'representative',
#  'industrial',
#  'administrator',
#  'file/office',
#  'clerk',
#  'civil',
#  '3d',
#  'designer',
#  'senior',
#  'implementation',
#  'consultant',
#  'financial',
#  'manager',
#  'administrative',
#  'operational',
#  'manager',
#  'divorce',
#  'clerk',
#  'statistician',
#  'data',
#  'analyst',
#  'software',
#  'development',
#  'lead',
#  'dynamics',
#  'ax',
#  'solution',
#  'architect',
#  'statistical',
#  'data',
#  'analyst',
#  'operations',
#  'manager',
#  'safety',
#  'officer',
#  'b.c',
#  'accounts',
#  'payable',
#  'clerk',
#  'payroll',
#  'clerk',
#  'accounting',
#  'team',
#  'leader',
#  'software',
#  'developer',
#  'c',
#  'etl\\bi',
#  'consultant',
#  'inventory',
#  'systems',
#  'supervisor',
#  'hair',
#  'makeup',
#  'assistant',
#  'construction',
#  'laborer/',
#  'carpenter',
#  'apprentice',
#  'customer',
#  'support',
#  'associate',
#  'casual',
#  'licenced',
#  'practical',
#  'nurse',
#  'accounting',
#  'assistant',
#  'accounts',
#  'payable',
#  'clerk',
#  'payroll',
#  'clerk',
#  'assistant',
#  'juice',
#  'bar',
#  'attendant',
#  'director',
#  'operations',
#  'sales',
#  'marketing',
#  'dental',
#  'office',
#  'administator',
#  'support',
#  'clerk',
#  'utility',
#  'operations',
#  'clerk',
#  'timekeeping',
#  'senior',
#  'product',
#  'software',
#  'engineer',
#  'loss',
#  'prevention',
#  'manager',
#  'senior',
#  'debt',
#  'consultant',
#  'sales',
#  'marketing',
#  'associate',
#  'co-op',
#  'corporate',
#  'finance',
#  'strategy',
#  'consultant',
#  'page/',
#  'library',
#  'clerk',
#  '1',
#  'payroll',
#  'accounts',
#  'payable',
#  'administrator',
#  'window',
#  'installer',
#  'helper',
#  'administrative',
#  'support',
#  'personnel',
#  'analyst',
#  'professional',
#  'services',
#  'technical',
#  'support',
#  'network',
#  'data',
#  'administrator',
#  'radiology',
#  'clerk',
#  'volunteer',
#  'security',
#  'guard',
#  'sales',
#  'assistant/administrator',
#  'application',
#  'developer',
#  'consultant',
#  'event',
#  'planner',
#  'bartender',
#  'department',
#  "'s",
#  'secretary',
#  'senior',
#  'software',
#  'agile',
#  'engineer',
#  'product',
#  'testing',
#  'engineer',
#  'part-time',
#  'job',
#  'teaching',
#  'assistant',
#  'owner',
#  'operator',
#  'payroll',
#  'clerk',
#  'programmer/system',
#  'administrator',
#  'software',
#  'development',
#  'assistant',
#  'senior',
#  'manager',
#  'structured',
#  'finance',
#  'quality',
#  'assurance',
#  'manager/release',
#  'manager',
#  'freelance',
#  'data',
#  'scientist',
#  'engineer',
#  'personal',
#  'accounts',
#  'manager',
#  'bather',
#  'dryer',
#  'account',
#  'executive',
#  'enterprise',
#  'guest',
#  'makeup',
#  'artist',
#  'computer',
#  'hardware',
#  'software',
#  'technician',
#  'meter',
#  'technician',
#  'lab',
#  'technician',
#  'volunteer',
#  'senior',
#  'system',
#  'developer',
#  'account',
#  'executive',
#  'acquisition',
#  'advertising',
#  'intern',
#  'farm',
#  'owner',
#  'data',
#  'entry',
#  'clerk',
#  'program',
#  'assistant',
#  'devops',
#  'developer',
#  'production',
#  'testing',
#  'sales',
#  'administrator',
#  'technician',
#  'payroll',
#  'accounting',
#  'student',
#  'enrollment',
#  'officer',
#  'freelancer',
#  'business',
#  'consultant',
#  'supervisor',
#  'education',
#  'teacher',
#  'produce',
#  'clerk',
#  'p/t',
#  'project',
#  'leader',
#  'product',
#  'development',
#  'team',
#  'tally/data',
#  'entry',
#  'clerk',
#  'relationship',
#  'support',
#  'manager',
#  'financial',
#  'clerk-corporate',
#  'payables',
#  'administrator',
#  'waitress',
#  'assistant',
#  'rim',
#  'business',
#  'development',
#  'manager',
#  'pt',
#  'professor',
#  'part',
#  'time',
#  'deli',
#  'clerk',
#  'account',
#  'manager',
#  'technical',
#  'inside',
#  'sales',
#  'hair',
#  'styling',
#  'assistant',
#  'food',
#  'server',
#  '-part',
#  'time',
#  'data',
#  'architect',
#  'modelling',
#  'control',
#  'analyst',
#  'financial',
#  'analyst',
#  'sr.',
#  'financial',
#  'analyst',
#  'assistant',
#  'general',
#  'secretary',
#  'personal',
#  'financial',
#  'advisor',
#  'desjardins',
#  'retail',
#  'sales',
#  'associative/sales',
#  'clerk',
#  'msa/porter/',
#  'ward',
#  'clerk',
#  'senior',
#  'programmer',
#  'software',
#  'engineer',
#  'oracle',
#  'trainer',
#  'english',
#  'speaking',
#  'technical',
#  'customer',
#  'service',
#  'representative',
#  'wharehouse',
#  'cleaner',
#  'project',
#  'development',
#  'coordinator',
#  'financial',
#  'database',
#  'manager',
#  'principal',
#  'network',
#  'engineer',
#  'data',
#  'center',
#  'operations',
#  'divisional',
#  'secretary',
#  'accountant',
#  'salesman',
#  'hostess/hair',
#  'stylist',
#  'financial',
#  'reconcilliation',
#  'analyst',
#  'school',
#  'manager',
#  'bookkeeper',
#  'payroll',
#  'income',
#  'tax',
#  'preparer',
#  'sdn/cloud',
#  'architect',
#  'consultant/assistant',
#  'manager',
#  'accounts',
#  'payable',
#  'clerk/',
#  'payroll',
#  'clerk',
#  'co-op',
#  'mac',
#  'sales',
#  'consultant',
#  '``',
#  'cleaner',
#  'janitor',
#  "''",
#  'relationship',
#  'manager',
#  'financial',
#  'service',
#  'representative',
#  'driver/crew',
#  'boss',
#  'data',
#  'center',
#  'analyst',
#  'tradesman',
#  'manufacturing',
#  'production',
#  'worker',
#  'relief',
#  'shipper',
#  'waiter',
#  'boat',
#  'washer',
#  'cashier',
#  'supervisor/payroll',
#  'clerk',
#  'clinical',
#  'pharmacist',
#  'corporate',
#  'payroll',
#  'clerk',
#  'production',
#  'worker',
#  'lead',
#  'hand',
#  'project',
#  'engineer/',
#  'assistant',
#  'project',
#  'manager',
#  'cashier',
#  'vendor',
#  'server',
#  'halifax',
#  'business',
#  'development',
#  'inside',
#  'sales',
#  'payroll',
#  'clerk',
#  'mazda',
#  'kia',
#  'senior',
#  'bi',
#  'architect',
#  'business',
#  'intelligence',
#  'administrator',
#  'developer',
#  'bistro',
#  'waiter',
#  'sales',
#  'associate/guitar',
#  'technician',
#  'budget',
#  'specialist',
#  'line',
#  'director',
#  'chief',
#  'administrative',
#  'officer',
#  'secretary',
#  'treasurer',
#  'employee',
#  'services',
#  'clerk',
#  'data',
#  'enrty',
#  'clerk',
#  'technical',
#  'assistant',
#  'casual',
#  'financial',
#  'department',
#  'manager',
#  'assistant',
#  'camera',
#  'operator',
#  'movie',
#  'assistant',
#  'professor',
#  'mathematics',
#  'management',
#  'trainee',
#  'enterprise-rent-a-car',
#  'medical',
#  'office',
#  'assistant/receptionist/medical',
#  'records',
#  'clerk',
#  'head',
#  'shoppe',
#  'hair',
#  'stylist',
#  'interior',
#  'decorating',
#  'consultant',
#  'hair',
#  'apprentice',
#  '.net',
#  'full',
#  'stack',
#  'developer',
#  'consultant',
#  'director',
#  'financial',
#  'reporting',
#  'accounting',
#  'vehicle',
#  'fleet',
#  'attendant',
#  'back-office',
#  'administrator',
#  'diligent',
#  'waiter',
#  'cooker',
#  'waiter',
#  'server/',
#  'dishwasher',
#  'wireless',
#  'network',
#  'technician',
#  'health',
#  'promotion',
#  'consultant',
#  'dining',
#  'room',
#  'supervisor',
#  'seasonal',
#  'piano',
#  'math',
#  'tutor',
#  'science',
#  'lab',
#  'assistant',
#  'project',
#  'manager',
#  'steel',
#  'structure',
#  'payroll',
#  'operator',
#  'administrative',
#  'assistant',
#  'payroll',
#  'clerk',
#  'operations',
#  'support',
#  'client',
#  'project',
#  'manager',
#  'financial',
#  'manager',
#  'investments',
#  'wealth',
#  'standby',
#  'technical',
#  'support',
#  'engineer',
#  'client',
#  'administrative/parts',
#  'clerk',
#  'customer',
#  'service',
#  'delivery',
#  'driver',
#  'office',
#  'administrator/billing',
#  'clerk',
#  'head',
#  'creative',
#  'designer',
#  'buster',
#  '/waiter/host',
#  'software',
#  'engineer',
#  'performance',
#  'analyst',
#  'web',
#  'analyst',
#  'qa',
#  'assistant',
#  'software',
#  'development',
#  'engineer',
#  'intern',
#  'embedded',
#  'software',
#  'developer',
#  'co-op',
#  'travel',
#  'office',
#  'accounting',
#  'supervisor',
#  'part-time',
#  'housekeeper',
#  'drivers',
#  'payroll',
#  'clerk/invoicing/billing',
#  'clerk',
#  'senior',
#  'qa',
#  'associate',
#  'financial',
#  'customer',
#  'service',
#  'assistant',
#  'apprentice',
#  ...]

# %%
import pandas as pd
ititles_df = pd.DataFrame(titles_list,columns = ['title']) 
ititles_df.head()
# Out:
#         title
# 0       front
# 1        desk
# 2  supervisor
# 3     janitor
# 4        lead

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mp
import numpy as np

in_titles = ititles_df.groupby('title').size().sort_values(ascending=False).head(20)
plt.figure(figsize=(20,10))

likeability_scores = np.array(in_titles)
 
data_normalizer = mp.colors.Normalize()

color_map = mp.colors.LinearSegmentedColormap(
    "my_map",
    {
        "red": [(0, 0.50, 0.5),
                 (1.0, 0, 0)],
        "green": [(0, 0.5, 1.0),
                (1.0, 0.5, 1.0)],
        "blue": [ (0, 0.5, 0.5),
                  (1.0, 0, 0)]
    }
)
    

in_titles.plot(kind="bar",alpha=0.9,color=color_map(data_normalizer(likeability_scores)),edgecolor='green')
plt.ylabel('Frequency', fontsize = 13, weight = 'bold')
plt.xlabel('Job title', fontsize = 13, weight = 'bold')
plt.rcParams['font.family'] = "serif"
plt.xticks(fontsize='14')
plt.yticks(fontsize='14')
plt.title('Top 20 job titles',fontsize='16',y=1.02)

plt.show()

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

p = sns.countplot(data=ititles_df,x="title")

# %%
jaccard_d = spark.sql("SELECT jaccard,job_title FROM data group by jaccard,job_title")
jaccard_df = jaccard_d.toPandas()
jaccard_df
# Out:
#          jaccard                                          job_title
# 0       0.500000                                [senior, associate]
# 1       0.666667                     [payroll, accounting, manager]
# 2       0.666667                            [relationship, manager]
# 3       0.500000                        [technical, support, agent]
# 4       0.750000                          [gas, station, attendant]
# 5       1.000000                                      [math, tutor]
# 6       0.500000                             [documentation, clerk]
# 7       1.000000                                           [busser]
# 8       0.500000         [shipping, coordinator, customer, service]
# 9       0.500000                                  [barista, waiter]
# 10      1.000000                                [warehouse, worker]
# 11      0.500000                   [housekeeping/public, attendant]
# 12      0.500000              [senior, production, system, analyst]
# 13      0.500000                   [sales, representative, cashier]
# 14      0.500000                                [senior, assembler]
# 15      1.000000                                    [food, adviser]
# 16      0.500000                               [front, desk, staff]
# 17      0.500000                                 [systems, analyst]
# 18      0.666667                  [business, relationship, manager]
# 19      0.500000                                  [cosmetic, buyer]
# 20      0.500000                           [electronic, technician]
# 21      0.600000                [real, estate, assistant, seasonal]
# 22      0.500000                              [registration, clerk]
# 23      0.666667                             [office, sales, clerk]
# 24      0.500000                               [android, developer]
# 25      0.666667                         [india, office, secretary]
# 26      0.500000                            [professional, athlete]
# 27      0.500000   [administrative, assistant, personal, assistant]
# 28      0.750000                      [software, systems, engineer]
# 29      0.500000                              [software, associate]
# ...          ...                                                ...
# 138048  0.500000                                [chief, data, tech]
# 138049  0.666667                          [tax, preparation, clerk]
# 138050  0.500000               [process, engineer, plm, consultant]
# 138051  0.500000            [office, assistant, summer, employment]
# 138052  0.500000                [corporate, sales/admin, assistant]
# 138053  0.500000        [warranty, service, coordinator, purchaser]
# 138054  0.500000          [warehouse, associate, general, labourer]
# 138055  1.000000                       [operations, analyst, sales]
# 138056  0.600000       [switchboard, operator/, front, desk, agent]
# 138057  0.500000                         [area, contracts, manager]
# 138058  0.666667              [maintenance, electronic, technician]
# 138059  0.666667               [dealer, compliance, representative]
# 138060  0.500000  [senior, assistant, manager, assistant, manage...
# 138061  0.500000                   [shipping, receiving, lead-hand]
# 138062  0.500000             [supervisor, event, customer, service]
# 138063  0.500000                       [java, back, end, developer]
# 138064  0.500000                         [ar, collections, analyst]
# 138065  0.666667                      [accountant, tax, consultant]
# 138066  0.500000                         [developer, data, analyst]
# 138067  0.600000  [customer, service, representative, secretaria...
# 138068  0.500000                                [facility, monitor]
# 138069  0.500000                        [shared, services, manager]
# 138070  0.666667                   [assisstant, territory, manager]
# 138071  0.500000                     [merchandise, flow, associate]
# 138072  0.500000                                 [git, illustrator]
# 138073  0.500000                             [cashier/order, taker]
# 138074  0.666667                    [exploration, cost, accountant]
# 138075  0.500000        [distance, learning, coordinator/secretary]
# 138076  0.750000              [office, clerk, accounts, receivable]
# 138077  0.500000                             [manuscript, reviewer]
#
# [138078 rows x 2 columns]

# %%
hist_df = jaccard_df['jaccard'].value_counts().rename('count')
hist_df = hist_df.to_frame().reset_index().rename({'index':'jaccard'},axis=1)
hist_df
# Out:
#     jaccard  count
# 0  0.500000  85851
# 1  0.666667  32161
# 2  0.600000   6964
# 3  1.000000   6777
# 4  0.750000   6097
# 5  0.800000    131
# 6  0.571429     90
# 7  0.833333      4
# 8  0.714286      3

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import hist
hist(hist_df['jaccard'], weights=hist_df['count'])
plt.ylabel('Count of Resume', fontsize=12)
plt.xlabel('Jaccard value', fontsize=12)
plt.grid(color='grey', linestyle='-', linewidth=0.5)

# %%
jaccard_df
# Out:
#          jaccard                                          job_title
# 0       0.500000                                [senior, associate]
# 1       0.666667                     [payroll, accounting, manager]
# 2       0.666667                            [relationship, manager]
# 3       0.500000                        [technical, support, agent]
# 4       0.750000                          [gas, station, attendant]
# 5       1.000000                                      [math, tutor]
# 6       0.500000                             [documentation, clerk]
# 7       1.000000                                           [busser]
# 8       0.500000         [shipping, coordinator, customer, service]
# 9       0.500000                                  [barista, waiter]
# 10      1.000000                                [warehouse, worker]
# 11      0.500000                   [housekeeping/public, attendant]
# 12      0.500000              [senior, production, system, analyst]
# 13      0.500000                   [sales, representative, cashier]
# 14      0.500000                                [senior, assembler]
# 15      1.000000                                    [food, adviser]
# 16      0.500000                               [front, desk, staff]
# 17      0.500000                                 [systems, analyst]
# 18      0.666667                  [business, relationship, manager]
# 19      0.500000                                  [cosmetic, buyer]
# 20      0.500000                           [electronic, technician]
# 21      0.600000                [real, estate, assistant, seasonal]
# 22      0.500000                              [registration, clerk]
# 23      0.666667                             [office, sales, clerk]
# 24      0.500000                               [android, developer]
# 25      0.666667                         [india, office, secretary]
# 26      0.500000                            [professional, athlete]
# 27      0.500000   [administrative, assistant, personal, assistant]
# 28      0.750000                      [software, systems, engineer]
# 29      0.500000                              [software, associate]
# ...          ...                                                ...
# 138048  0.500000                                [chief, data, tech]
# 138049  0.666667                          [tax, preparation, clerk]
# 138050  0.500000               [process, engineer, plm, consultant]
# 138051  0.500000            [office, assistant, summer, employment]
# 138052  0.500000                [corporate, sales/admin, assistant]
# 138053  0.500000        [warranty, service, coordinator, purchaser]
# 138054  0.500000          [warehouse, associate, general, labourer]
# 138055  1.000000                       [operations, analyst, sales]
# 138056  0.600000       [switchboard, operator/, front, desk, agent]
# 138057  0.500000                         [area, contracts, manager]
# 138058  0.666667              [maintenance, electronic, technician]
# 138059  0.666667               [dealer, compliance, representative]
# 138060  0.500000  [senior, assistant, manager, assistant, manage...
# 138061  0.500000                   [shipping, receiving, lead-hand]
# 138062  0.500000             [supervisor, event, customer, service]
# 138063  0.500000                       [java, back, end, developer]
# 138064  0.500000                         [ar, collections, analyst]
# 138065  0.666667                      [accountant, tax, consultant]
# 138066  0.500000                         [developer, data, analyst]
# 138067  0.600000  [customer, service, representative, secretaria...
# 138068  0.500000                                [facility, monitor]
# 138069  0.500000                        [shared, services, manager]
# 138070  0.666667                   [assisstant, territory, manager]
# 138071  0.500000                     [merchandise, flow, associate]
# 138072  0.500000                                 [git, illustrator]
# 138073  0.500000                             [cashier/order, taker]
# 138074  0.666667                    [exploration, cost, accountant]
# 138075  0.500000        [distance, learning, coordinator/secretary]
# 138076  0.750000              [office, clerk, accounts, receivable]
# 138077  0.500000                             [manuscript, reviewer]
#
# [138078 rows x 2 columns]

# %%
count = 0
for i in jaccard_df['job_title']:
    if len(i)>1:
        count += 1
print("Number of Resumes that have job tokens greater than 1 are: " + str(count))
# Out:
# Number of Resumes that have job tokens greater than 1 are: 136506

# %%
mask = jaccard_df['job_title'].str.len() > 1
jaccard_2 = jaccard_df.loc[mask]
sc1 = jaccard_2['jaccard'].value_counts().rename('count')
sc1 = sc1.to_frame().reset_index().rename({'index':'jaccard'},axis=1)
sc1
# Out:
#     jaccard  count
# 0  0.500000  84975
# 1  0.666667  32161
# 2  0.600000   6964
# 3  0.750000   6097
# 4  1.000000   6081
# 5  0.800000    131
# 6  0.571429     90
# 7  0.833333      4
# 8  0.714286      3

# %%
mask1 = jaccard_df['job_title'].str.len() == 1
jaccard_3 = jaccard_df.loc[mask1]
sc2 = jaccard_2['jaccard'].value_counts().rename('count')
sc2 = sc2.to_frame().reset_index().rename({'index':'jaccard'},axis=1)
sc2
# Out:
#     jaccard  count
# 0  0.500000  84975
# 1  0.666667  32161
# 2  0.600000   6964
# 3  0.750000   6097
# 4  1.000000   6081
# 5  0.800000    131
# 6  0.571429     90
# 7  0.833333      4
# 8  0.714286      3

# %%
decimals = 2    
sc2['jaccard'] = sc2['jaccard'].apply(lambda x: round(x, decimals))
sc2
# Out:
#    jaccard  count
# 0     0.50  84975
# 1     0.67  32161
# 2     0.60   6964
# 3     0.75   6097
# 4     1.00   6081
# 5     0.80    131
# 6     0.57     90
# 7     0.83      4
# 8     0.71      3

# %%
fig, ax = plt.subplots(1, 2,figsize=(20,5))

ax[0].hist(jaccard_2['jaccard'])
ax[0].set_xlabel('Jaccard Value')
ax[0].set_ylabel('count')
ax[0].grid(color='grey', linestyle='-', linewidth=0.5)
ax[0].set_title('Jaccard value for 2 tokens of Job titles')


ax[1].hist(jaccard_3['jaccard'])
ax[1].set_xlabel('Jaccard Value')
ax[1].set_ylabel('count')
ax[1].grid(color='grey', linestyle='-', linewidth=0.5)
ax[1].set_title('Jaccard value for 1 token of Job titles')


#ax[0].bar(sc2['jaccard'],sc2['count'])

# sc1["jaccard"].plot(ax=ax[0],kind='bar')
#ax[0].set_xlim(0,0.5)
# Out:
# Text(0.5, 1.0, 'Jaccard value for 1 token of Job titles')
